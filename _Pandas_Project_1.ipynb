# %% [markdown]
# # Project_Pandas

# %%
import pandas as pd

# %%
titanic=pd.read_csv('C:/Users/HP/Documents/script/2.1 Course_Materials_Part1/Course_Materials_Part1/Video_Lecture_NBs/titanic.csv')

# %%
#pandas_display_option_&_Method_Head_&_Tail()

# %%
print(titanic)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
pd.options.display.max_rows
# Out:
# 60

# %%
pd.options.display.min_rows
# Out:
# 10

# %%
titanic.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0          0       3    male  22.0      1      0   7.2500        S  NaN
# 1          1       1  female  38.0      1      0  71.2833        C    C
# 2          1       3  female  26.0      0      0   7.9250        S  NaN
# 3          1       1  female  35.0      1      0  53.1000        S    C
# 4          0       3    male  35.0      0      0   8.0500        S  NaN
# 5          0       3    male   NaN      0      0   8.4583        Q  NaN
# 6          0       1    male  54.0      0      0  51.8625        S    E
# 7          0       3    male   2.0      3      1  21.0750        S  NaN
# 8          1       3  female  27.0      0      2  11.1333        S  NaN
# 9          1       2  female  14.0      1      0  30.0708        C  NaN
# 10         1       3  female   4.0      1      1  16.7000        S    G
# 11         1       1  female  58.0      0      0  26.5500        S    C
# ...

# %%
titanic.tail(10)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 881         0       3    male  33.0      0      0   7.8958        S  NaN
# 882         0       3  female  22.0      0      0  10.5167        S  NaN
# 883         0       2    male  28.0      0      0  10.5000        S  NaN
# 884         0       3    male  25.0      0      0   7.0500        S  NaN
# 885         0       3  female  39.0      0      5  29.1250        Q  NaN
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN

# %%
#data_inspection

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic.describe(include="O")
# Out:
#          sex embarked deck
# count    891      889  203
# unique     2        3    7
# top     male        S    C
# freq     577      644   59

# %% [markdown]
# # python_built_in_funcation_&_Data_frame_Attributes_&_method

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
#Data_frame_&_build_in_Funcation

# %%
type(titanic)
# Out:
# pandas.core.frame.DataFrame

# %%
len(titanic)
# Out:
# 891

# %%
round(titanic)
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked deck
# 0           0       3    male  22.0      1      0   7.0        S  NaN
# 1           1       1  female  38.0      1      0  71.0        C    C
# 2           1       3  female  26.0      0      0   8.0        S  NaN
# 3           1       1  female  35.0      1      0  53.0        S    C
# 4           0       3    male  35.0      0      0   8.0        S  NaN
# ..        ...     ...     ...   ...    ...    ...   ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0        S  NaN
# 887         1       1  female  19.0      0      0  30.0        S    B
# 888         0       3  female   NaN      1      2  23.0        S  NaN
# 889         1       1    male  26.0      0      0  30.0        C    C
# 890         0       3    male  32.0      0      0   8.0        Q  NaN
#
# [891 rows x 9 columns]

# %%
min(titanic)
# Out:
# 'age'

# %%
#Data_frame_attributes

# %%
titanic.shape
# Out:
# (891, 9)

# %%
titanic.size
# Out:
# 8019

# %%
titanic.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'deck'],
#       dtype='object')

# %%
#Data_frame_method

# %%
titanic.head(n=5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
titanic.min()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14312\3376850614.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   titanic.min()
# survived         0
# pclass           1
# sex         female
# age           0.42
# sibsp            0
# parch            0
# fare           0.0
# dtype: object

# %%
#method_changing

# %%
titanic.mean()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14312\929819788.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   titanic.mean()
# survived     0.383838
# pclass       2.308642
# age         29.699118
# sibsp        0.523008
# parch        0.381594
# fare        32.204208
# dtype: float64

# %%
titanic.mean().sort_values().head(2)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14312\205917541.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   titanic.mean().sort_values().head(2)
# parch       0.381594
# survived    0.383838
# dtype: float64

# %%
#Make_it_easy:TAB Completion And Tooltip

# %%
titanic.sort_values(by="age",ascending=False)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 630         1       1    male  80.0      0      0  30.0000        S    A
# 851         0       3    male  74.0      0      0   7.7750        S  NaN
# 493         0       1    male  71.0      0      0  49.5042        C  NaN
# 96          0       1    male  71.0      0      0  34.6542        C    A
# 116         0       3    male  70.5      0      0   7.7500        Q  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 859         0       3    male   NaN      0      0   7.2292        C  NaN
# 863         0       3  female   NaN      8      2  69.5500        S  NaN
# 868         0       3    male   NaN      0      0   9.5000        S  NaN
# 878         0       3    male   NaN      0      0   7.8958        S  NaN
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
#
# [891 rows x 9 columns]

# %%
#Selecting_Columns

# %%
titanic[['age','sex']]
# Out:
#       age     sex
# 0    22.0    male
# 1    38.0  female
# 2    26.0  female
# 3    35.0  female
# 4    35.0    male
# ..    ...     ...
# 886  27.0    male
# 887  19.0  female
# 888   NaN  female
# 889  26.0    male
# 890  32.0    male
#
# [891 rows x 2 columns]

# %%
type(titanic[['age','sex']])
# Out:
# pandas.core.frame.DataFrame

# %%
type(titanic[['age']])
# Out:
# pandas.core.frame.DataFrame

# %%
#selecting_one_column_with"dot_notation"

# %%
titanic.age.equals(titanic['age'])
# Out:
# True

# %%
#position_base_indexing_and_slicing_with_iloc[]

# %%
import pandas as pd

# %%
summer= pd.read_csv('C:/Users/HP/Documents/script/2.1 Course_Materials_Part1/Course_Materials_Part1/Video_Lecture_NBs/summer.csv',index_col="Athlete")

# %%
summer.reset_index()
# Out:
#                          Athlete  Year    City      Sport  \
# 0                  HAJOS, Alfred  1896  Athens   Aquatics
# 1               HERSCHMANN, Otto  1896  Athens   Aquatics
# 2              DRIVAS, Dimitrios  1896  Athens   Aquatics
# 3             MALOKINIS, Ioannis  1896  Athens   Aquatics
# 4             CHASAPIS, Spiridon  1896  Athens   Aquatics
# ...                          ...   ...     ...        ...
# 31160         JANIKOWSKI, Damian  2012  London  Wrestling
# 31161  REZAEI, Ghasem Gholamreza  2012  London  Wrestling
# 31162             TOTROV, Rustam  2012  London  Wrestling
# 31163          ALEKSANYAN, Artur  2012  London  Wrestling
# 31164             LIDBERG, Jimmy  2012  London  Wrestling
#
#                 Discipline Country Gender                       Event   Medal
# 0                 Swimming     HUN    Men              100M Freestyle    Gold
# 1                 Swimming     AUT    Men              100M Freestyle  Silver
# ...

# %%
#select_rows_with_iloc[]

# %%
summer.iloc[0]
# Out:
# Year                    1896
# City                  Athens
# Sport               Aquatics
# Discipline          Swimming
# Country                  HUN
# Gender                   Men
# Event         100M Freestyle
# Medal                   Gold
# Name: HAJOS, Alfred, dtype: object

# %%
type(summer.iloc[0])
# Out:
# pandas.core.series.Series

# %%
#filter_first_row_horizental
summer.iloc[0]
# Out:
# Year                    1896
# City                  Athens
# Sport               Aquatics
# Discipline          Swimming
# Country                  HUN
# Gender                   Men
# Event         100M Freestyle
# Medal                   Gold
# Name: HAJOS, Alfred, dtype: object

# %%
#second_row

summer.iloc[1]
# Out:
# Year                    1896
# City                  Athens
# Sport               Aquatics
# Discipline          Swimming
# Country                  AUT
# Gender                   Men
# Event         100M Freestyle
# Medal                 Silver
# Name: HERSCHMANN, Otto, dtype: object

# %%
 #last_row
summer.iloc[-2]
# Out:
# Year                         2012
# City                       London
# Sport                   Wrestling
# Discipline    Wrestling Freestyle
# Country                       ARM
# Gender                        Men
# Event                    Wg 96 KG
# Medal                      Bronze
# Name: ALEKSANYAN, Artur, dtype: object

# %%
#filter_multiple_rows
summer.iloc[[1,2,34]]
# Out:
#                    Year    City      Sport Discipline Country Gender  \
# Athlete
# HERSCHMANN, Otto   1896  Athens   Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios  1896  Athens   Aquatics   Swimming     GRE    Men
# GARRETT, Robert    1896  Athens  Athletics  Athletics     USA    Men
#
#                                         Event   Medal
# Athlete
# HERSCHMANN, Otto               100M Freestyle  Silver
# DRIVAS, Dimitrios  100M Freestyle For Sailors  Bronze
# GARRETT, Robert                     Long Jump  Silver

# %%
summer.iloc[1:3]
# Out:
#                    Year    City     Sport Discipline Country Gender  \
# Athlete
# HERSCHMANN, Otto   1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                         Event   Medal
# Athlete
# HERSCHMANN, Otto               100M Freestyle  Silver
# DRIVAS, Dimitrios  100M Freestyle For Sailors  Bronze

# %%
summer.iloc[0:5]
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred       1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HAJOS, Alfred                   100M Freestyle    Gold
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon  100M Freestyle For Sailors  Silver

# %%
#last_rows
summer.iloc[-5:]
# Out:
#                            Year    City      Sport           Discipline  \
# Athlete
# JANIKOWSKI, Damian         2012  London  Wrestling  Wrestling Freestyle
# REZAEI, Ghasem Gholamreza  2012  London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam             2012  London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur          2012  London  Wrestling  Wrestling Freestyle
# LIDBERG, Jimmy             2012  London  Wrestling  Wrestling Freestyle
#
#                           Country Gender     Event   Medal
# Athlete
# JANIKOWSKI, Damian            POL    Men  Wg 84 KG  Bronze
# REZAEI, Ghasem Gholamreza     IRI    Men  Wg 96 KG    Gold
# TOTROV, Rustam                RUS    Men  Wg 96 KG  Silver
# ALEKSANYAN, Artur             ARM    Men  Wg 96 KG  Bronze
# LIDBERG, Jimmy                SWE    Men  Wg 96 KG  Bronze

# %%
summer.iloc[-5:-1]
# Out:
#                            Year    City      Sport           Discipline  \
# Athlete
# JANIKOWSKI, Damian         2012  London  Wrestling  Wrestling Freestyle
# REZAEI, Ghasem Gholamreza  2012  London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam             2012  London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur          2012  London  Wrestling  Wrestling Freestyle
#
#                           Country Gender     Event   Medal
# Athlete
# JANIKOWSKI, Damian            POL    Men  Wg 84 KG  Bronze
# REZAEI, Ghasem Gholamreza     IRI    Men  Wg 96 KG    Gold
# TOTROV, Rustam                RUS    Men  Wg 96 KG  Silver
# ALEKSANYAN, Artur             ARM    Men  Wg 96 KG  Bronze

# %%
#columns_level

# %%
summer
# Out:
#                            Year    City      Sport           Discipline  \
# Athlete
# HAJOS, Alfred              1896  Athens   Aquatics             Swimming
# HERSCHMANN, Otto           1896  Athens   Aquatics             Swimming
# DRIVAS, Dimitrios          1896  Athens   Aquatics             Swimming
# MALOKINIS, Ioannis         1896  Athens   Aquatics             Swimming
# CHASAPIS, Spiridon         1896  Athens   Aquatics             Swimming
# ...                         ...     ...        ...                  ...
# JANIKOWSKI, Damian         2012  London  Wrestling  Wrestling Freestyle
# REZAEI, Ghasem Gholamreza  2012  London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam             2012  London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur          2012  London  Wrestling  Wrestling Freestyle
# LIDBERG, Jimmy             2012  London  Wrestling  Wrestling Freestyle
#
#                           Country Gender                       Event   Medal
# Athlete
# ...

# %%
summer.iloc[0,4]
# Out:
# 'HUN'

# %%
summer.iloc[0,:3]
# Out:
# Year         1896
# City       Athens
# Sport    Aquatics
# Name: HAJOS, Alfred, dtype: object

# %%
summer.iloc[0,[1,4,5]]
# Out:
# City       Athens
# Country       HUN
# Gender        Men
# Name: HAJOS, Alfred, dtype: object

# %%
summer.iloc[2:5,[1,4,5]]
# Out:
#                       City Country Gender
# Athlete
# DRIVAS, Dimitrios   Athens     GRE    Men
# MALOKINIS, Ioannis  Athens     GRE    Men
# CHASAPIS, Spiridon  Athens     GRE    Men

# %%
summer.iloc[:,5]
# Out:
# Athlete
# HAJOS, Alfred                Men
# HERSCHMANN, Otto             Men
# DRIVAS, Dimitrios            Men
# MALOKINIS, Ioannis           Men
# CHASAPIS, Spiridon           Men
#                             ...
# JANIKOWSKI, Damian           Men
# REZAEI, Ghasem Gholamreza    Men
# TOTROV, Rustam               Men
# ALEKSANYAN, Artur            Men
# LIDBERG, Jimmy               Men
# Name: Gender, Length: 31165, dtype: object

# %%
summer.iloc[[1,3],3:]
# Out:
#                    Discipline Country Gender                       Event  \
# Athlete
# HERSCHMANN, Otto     Swimming     AUT    Men              100M Freestyle
# MALOKINIS, Ioannis   Swimming     GRE    Men  100M Freestyle For Sailors
#
#                      Medal
# Athlete
# HERSCHMANN, Otto    Silver
# MALOKINIS, Ioannis    Gold

# %%
#selecting_rows_with_Loc[]

# %%
summer.iloc[2]
# Out:
# Year                                1896
# City                              Athens
# Sport                           Aquatics
# Discipline                      Swimming
# Country                              GRE
# Gender                               Men
# Event         100M Freestyle For Sailors
# Medal                             Bronze
# Name: DRIVAS, Dimitrios, dtype: object

# %%
summer.loc["DRIVAS, Dimitrios"]
# Out:
# Year                                1896
# City                              Athens
# Sport                           Aquatics
# Discipline                      Swimming
# Country                              GRE
# Gender                               Men
# Event         100M Freestyle For Sailors
# Medal                             Bronze
# Name: DRIVAS, Dimitrios, dtype: object

# %%
summer.loc[["PHELPS, Michael"],["Event","Medal"]]
# Out:
#                                   Event   Medal
# Athlete
# PHELPS, Michael          100M Butterfly    Gold
# PHELPS, Michael          200M Butterfly    Gold
# PHELPS, Michael          200M Freestyle  Bronze
# PHELPS, Michael  200M Individual Medley    Gold
# PHELPS, Michael  400M Individual Medley    Gold
# PHELPS, Michael  4X100M Freestyle Relay  Bronze
# PHELPS, Michael     4X100M Medley Relay    Gold
# PHELPS, Michael  4X200M Freestyle Relay    Gold
# PHELPS, Michael          100M Butterfly    Gold
# PHELPS, Michael          200M Butterfly    Gold
# PHELPS, Michael          200M Freestyle    Gold
# PHELPS, Michael  200M Individual Medley    Gold
# PHELPS, Michael  400M Individual Medley    Gold
# PHELPS, Michael  4X100M Freestyle Relay    Gold
# PHELPS, Michael     4X100M Medley Relay    Gold
# PHELPS, Michael  4X200M Freestyle Relay    Gold
# PHELPS, Michael          100M Butterfly    Gold
# PHELPS, Michael          200M Butterfly  Silver
# ...

# %%
summer.loc[:,["Country","Medal"]]
# Out:
#                           Country   Medal
# Athlete
# HAJOS, Alfred                 HUN    Gold
# HERSCHMANN, Otto              AUT  Silver
# DRIVAS, Dimitrios             GRE  Bronze
# MALOKINIS, Ioannis            GRE    Gold
# CHASAPIS, Spiridon            GRE  Silver
# ...                           ...     ...
# JANIKOWSKI, Damian            POL  Bronze
# REZAEI, Ghasem Gholamreza     IRI    Gold
# TOTROV, Rustam                RUS  Silver
# ALEKSANYAN, Artur             ARM  Bronze
# LIDBERG, Jimmy                SWE  Bronze
#
# [31165 rows x 2 columns]
